# %%
from epub import ebook

# %%
book = ebook('test_data/Sein Sohn - Charles Lewinsky.epub')
# Out:
# de
# checking language for hyphenation de
# Using language: de
# Buffer_stuff 0
# page:  {'page': 0, 'doc': 'tpl_2', 'line': 0}
# Page as image
# Buffer_stuff 1
# page:  {'page': 1, 'doc': 'tpl_2', 'line': 2}
# Buffer_stuff 2
# page:  {'page': 2, 'doc': 'tpl_4', 'line': 0}
# Page as image
# Buffer_stuff 3
# page:  {'page': 3, 'doc': 'tpl_6', 'line': 0}
# Buffer_stuff 4
# page:  {'page': 4, 'doc': 'chapter1', 'line': 0}
# Buffer_stuff 5
# page:  {'page': 5, 'doc': 'chapter2', 'line': 0}
# Buffer_stuff 6
# page:  {'page': 6, 'doc': 'chapter2', 'line': 22}

# %%
book.extract_metadata()
# Out:
# de
# {'author': 'Charles Lewinsky',
#  'title': OrderedDict([('@id', 'opf_title'), ('#text', 'Sein Sohn')]),
#  'dates': {'published': ''},
#  'cover': None,
#  'language': 'de'}

# %%
book.title
# Out:
# OrderedDict([('@id', 'opf_title'), ('#text', 'Sein Sohn')])

# %%
from IPython.display import Image

# %%
display(book.current_page())
# Out:
# <PIL.Image.Image image mode=L size=1072x1448 at 0x7F1CA6B4A128>

# %%
book.next_page()
# Out:
# rendering pages at middle of buffer: 6
# page:  {'page': 12, 'doc': 'chapter3', 'line': 44}
# <PIL.Image.Image image mode=L size=1072x1448 at 0x7F1CA71C8780>

# %%
book.previous_page()
# Out:
# 0
# 0 [0, 1, 2, 3, 4, 5, 6]
# it is stored reuse
# <PIL.Image.Image image mode=L size=1072x1448 at 0x7F1CA6B4A128>

# %%
book.language
# Out:
# 'en_US'

# %%
book.organisation
# Out:
# {'titlepage': 'titlepage.xhtml',
#  'fm-sup': 'OEBPS/Bair_9780679605058_epub3_fm-sup_r1.xhtml',
#  'tp': 'OEBPS/Bair_9780679605058_epub3_tp_r1.xhtml',
#  'cop': 'OEBPS/Bair_9780679605058_epub3_cop_r1.xhtml',
#  'inlinetoc': 'OEBPS/Bair_9780679605058_epub3_toc_r1.xhtml',
#  'epi': 'OEBPS/Bair_9780679605058_epub3_epi_r1.xhtml',
#  'loc': 'OEBPS/Bair_9780679605058_epub3_loc_r1.xhtml',
#  'map8': 'OEBPS/Bair_9780679605058_epub3_map_r1_split_000.xhtml',
#  'map7': 'OEBPS/Bair_9780679605058_epub3_map_r1_split_001.xhtml',
#  'map1': 'OEBPS/Bair_9780679605058_epub3_map1_r1.xhtml',
#  'map2': 'OEBPS/Bair_9780679605058_epub3_map2_r1.xhtml',
#  'map3': 'OEBPS/Bair_9780679605058_epub3_map3_r1.xhtml',
#  'map4': 'OEBPS/Bair_9780679605058_epub3_map4_r1.xhtml',
#  'map5': 'OEBPS/Bair_9780679605058_epub3_map5_r1.xhtml',
#  'fm-sup1': 'OEBPS/Bair_9780679605058_epub3_fm-sup1_r1.xhtml',
#  'map6': 'OEBPS/Bair_9780679605058_epub3_map6_r1.xhtml',
# ...
